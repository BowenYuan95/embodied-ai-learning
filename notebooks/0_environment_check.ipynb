# %% [markdown]
# # Lesson 0 — 环境检查
#
# 最小规模的 smoke test：这个 Python 环境能否导入项目所依赖的三个
# package，以及 PyTorch 能否看到 GPU？
#
# - `torch` — 训练与 tensor 运行时。
# - `mani_skill` — 提供 `PickCube-v1` 的 simulator。
# - `gymnasium` — ManiSkill 环境所遵循的环境 API。
#
# 预期输出：torch 版本、一个 CUDA 布尔值，以及一个 GPU 名称。如果 CUDA 为
# `False`，`get_device_name(0)` 调用会抛出异常而不是打印名称；这意味着
# 该环境是 CPU-only 的，后续某些步骤会回退到 CPU。
#
# 下方保存的输出记录于 2026-09-19，当时 CUDA 可用。它作为历史证据保留，
# 此处不再重新执行。

# %%
import torch
import mani_skill
import gymnasium

print("Python environment OK")
print("Torch:", torch.__version__)
print("CUDA:", torch.cuda.is_available())
print("GPU:", torch.cuda.get_device_name(0))
# Out:
# Python environment OK
# Torch: 2.11.0+cu128
# CUDA: True
# GPU: NVIDIA GeForce RTX 3080 Ti Laptop GPU
